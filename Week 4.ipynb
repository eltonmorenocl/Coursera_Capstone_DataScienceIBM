# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# # Cologne City Food Choice

# %% [markdown]
# # Part 1: Data about the districts of Cologne City

# %%
import numpy as np 
import pandas as pd 

# !conda install -c conda-forge lxml --yes
print("Libraries installed.")
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     lxml-4.4.1                 |   py36h7ec2d77_0         1.6 MB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     python_abi:      3.6-1_cp36m          conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                       --> 2020.4.5.1-hecc5488_0     conda-forge
#     certifi:         2020.4.5.1-py36_0                --> 2020.4.5.1-py36h9f0ad1d_0 conda-forge
#     lxml:            4.3.1-py36hefd8a0e_0             --> 4.4.1-py36h7ec2d77_0      conda-forge
#     openssl:         1.1.1g-h7b6447c_0                --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# certifi-2020.4.5.1   | 151 KB    | ##################################### | 100%
# lxml-4.4.1           | 1.6 MB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# ca-certificates-2020 | 146 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries installed.

# %% [markdown]
# ***A: I use pandas to create a dataframe from the table on the Wikipedia page.***

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Districts_of_Cologne#Districts')[1]

# %%
df
# Out:
#                                                   Map  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                                  Coat  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                         City district  \
# 0                          District 1 Köln-Innenstadt
# 1                        District 2 Köln-Rodenkirchen
# 2                          District 3 Köln-Lindenthal
# 3                           District 4 Köln-Ehrenfeld
# 4                              District 5 Köln-Nippes
# 5                          District 6 Köln-Chorweiler
# 6                                District 7 Köln-Porz
# 7                                District 8 Köln-Kalk
# 8                             District 9 Köln-Mülheim
# 9                                             Cologne
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                            City parts  \
# 0   Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1   Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2   Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3   Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4   Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5   Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6   Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7   Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8   Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
# 9                                                 NaN
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                                  Area  \
# 0                                            16.4 km²
# 1                                            54.6 km²
# 2                                            41.6 km²
# 3                                            23.8 km²
# 4                                            31.8 km²
# 5                                            67.2 km²
# 6                                            78.8 km²
# 7                                            38.2 km²
# 8                                            52.2 km²
# 9                                          405.15 km²
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                           Population1  \
# 0                                             127.033
# 1                                             100.936
# 2                                             137.552
# 3                                             103.621
# 4                                             110.092
# 5                                              80.870
# 6                                             106.520
# 7                                             108.330
# 8                                             144.374
# 9                                          1.019.3282
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                          Pop. density  \
# 0                                           7.746/km²
# 1                                           1.850/km²
# 2                                           3.308/km²
# 3                                           4.348/km²
# 4                                           3.462/km²
# 5                                           1.204/km²
# 6                                           1.352/km²
# 7                                           2.841/km²
# 8                                           2.764/km²
# 9                                           2.516/km²
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                     District Councils  \
# 0   Bezirksksamt Innenstadt Brückenstraße 19, D-50...
# 1   Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...
# 2   Bezirksamt Lindenthal Aachener Straße 220, 509...
# 3   Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...
# 4    Bezirksamt NippesNeusser Straße 450,D-50733 Köln
# 5   Bezirksamt Chorweiler Pariser Platz 1, D-50765...
# 6   Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...
# 7   Bezirksamt KalkKalker Hauptstraße 247–273,D-51...
# 8     Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln
# 9                                           2.516/km²
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                             Town Hall
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                           2.516/km²
# 10  Notes: 1: population as of 31. December 2008 2...

# %% [markdown]
# ***B: I drop columns which are not required.***

# %%
df.drop("Map", axis=1, inplace=True)

# %%
df.drop("Coat", axis=1, inplace=True)

# %%
df.drop("Town Hall", axis=1, inplace=True)

# %%
df["City district"]=df["City district"].str[11:]

# %%
df.head(12)
# Out:
#                                         City district  \
# 0                                     Köln-Innenstadt
# 1                                   Köln-Rodenkirchen
# 2                                     Köln-Lindenthal
# 3                                      Köln-Ehrenfeld
# 4                                         Köln-Nippes
# 5                                     Köln-Chorweiler
# 6                                           Köln-Porz
# 7                                           Köln-Kalk
# 8                                        Köln-Mülheim
# 9
# 10  opulation as of 31. December 2008 2: Statistic...
#
#                                            City parts  \
# 0   Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1   Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2   Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3   Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4   Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5   Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6   Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7   Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8   Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
# 9                                                 NaN
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                                  Area  \
# 0                                            16.4 km²
# 1                                            54.6 km²
# 2                                            41.6 km²
# 3                                            23.8 km²
# 4                                            31.8 km²
# 5                                            67.2 km²
# 6                                            78.8 km²
# 7                                            38.2 km²
# 8                                            52.2 km²
# 9                                          405.15 km²
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                           Population1  \
# 0                                             127.033
# 1                                             100.936
# 2                                             137.552
# 3                                             103.621
# 4                                             110.092
# 5                                              80.870
# 6                                             106.520
# 7                                             108.330
# 8                                             144.374
# 9                                          1.019.3282
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                          Pop. density  \
# 0                                           7.746/km²
# 1                                           1.850/km²
# 2                                           3.308/km²
# 3                                           4.348/km²
# 4                                           3.462/km²
# 5                                           1.204/km²
# 6                                           1.352/km²
# 7                                           2.841/km²
# 8                                           2.764/km²
# 9                                           2.516/km²
# 10  Notes: 1: population as of 31. December 2008 2...
#
#                                     District Councils
# 0   Bezirksksamt Innenstadt Brückenstraße 19, D-50...
# 1   Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...
# 2   Bezirksamt Lindenthal Aachener Straße 220, 509...
# 3   Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...
# 4    Bezirksamt NippesNeusser Straße 450,D-50733 Köln
# 5   Bezirksamt Chorweiler Pariser Platz 1, D-50765...
# 6   Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...
# 7   Bezirksamt KalkKalker Hauptstraße 247–273,D-51...
# 8     Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln
# 9                                           2.516/km²
# 10  Notes: 1: population as of 31. December 2008 2...

# %%
df.drop([10], inplace=True)

# %%
df.drop([9], inplace=True)

# %%
df
# Out:
#        City district                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5    Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6          Köln-Porz  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7          Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8       Köln-Mülheim  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
# 5  67.2 km²      80.870    1.204/km²
# 6  78.8 km²     106.520    1.352/km²
# 7  38.2 km²     108.330    2.841/km²
# 8  52.2 km²     144.374    2.764/km²
#
#                                    District Councils
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...
# 8    Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln

# %% [markdown]
# ***C: Print the number of rows in the dataframe with method shape.

# %%
df.shape
# Out:
# (9, 6)

# %% [markdown]
# # Part 2: Geospatial data from Foursquare

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0           conda-forge
#     geopy:         1.22.0-pyh9f0ad1d_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
geolocator = Nominatim(user_agent="Cologne_food")

df['Major_Dist_Coord']= df['City district'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
df[['Latitude', 'Longitude']] = df['Major_Dist_Coord'].apply(pd.Series)

df.drop(['Major_Dist_Coord'], axis=1, inplace=True)
df
# Out:
#        City district                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5    Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6          Köln-Porz  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7          Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8       Köln-Mülheim  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
# 5  67.2 km²      80.870    1.204/km²
# 6  78.8 km²     106.520    1.352/km²
# 7  38.2 km²     108.330    2.841/km²
# 8  52.2 km²     144.374    2.764/km²
#
#                                    District Councils   Latitude  Longitude
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...  50.906705   6.999129
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
# 8    Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln  50.958147   7.013526

# %% [markdown]
# # Part 3: Building clusters of the neighborhoods in Cologne City

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ***A: Geographical coordinates of Cologne***

# %%
address = 'Cologne'

geolocator = Nominatim(user_agent="Cologne_food")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Cologne are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Cologne are 50.938361, 6.959974.

# %% [markdown]
# ***B: Visualization of Cologne's neighborhoods***

# %%
# create map of Cologne using latitude and longitude 
map_cologne = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to the map
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['City district']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cologne) 
    
map_cologne
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ***C: Using Foursquare API, I will explore the neighborhoods of Cologne and segment them.***

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentails:
# CLIENT_ID: UT2CSTWIIPGBQHESMVORMMZF3Q21K0PKIVOYR10JAKO33TQN
# CLIENT_SECRET:I2ZWM3FHFXTB2O1MRVXRRM2VXNKHPHO2WALYG2MIF1G5HS5J

# %%
df.loc[0, 'City district']
# Out:
# 'Köln-Innenstadt'

# %% [markdown]
# ***D: Show the top 15 venues in Köln-Innenstadt within a radius of 600 meters.***

# %%
neighborhood_latitude = df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = df.loc[0, 'City district'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Köln-Innenstadt are 50.93732845, 6.959234323073302.

# %%
LIMIT = 15

radius = 600

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=UT2CSTWIIPGBQHESMVORMMZF3Q21K0PKIVOYR10JAKO33TQN&client_secret=I2ZWM3FHFXTB2O1MRVXRRM2VXNKHPHO2WALYG2MIF1G5HS5J&v=20180604&ll=50.93732845,6.959234323073302&radius=600&limit=15'

# %%
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                    name        categories        lat       lng
# 0      Craftbeer Corner          Beer Bar  50.937222  6.958928
# 1  Papa Joe's Jazzlokal         Jazz Club  50.937882  6.962241
# 2            LEGO Store  Toy / Game Store  50.937042  6.956370
# 3      Ice Cream United    Ice Cream Shop  50.935520  6.960180
# 4             El Chango        Steakhouse  50.936599  6.959978

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 15 venues were returned by Foursquare.

# %%
print ('{} unique categories in Köln-Innenstadt.'.format(nearby_venues['categories'].value_counts().shape[0]))
# Out:
# 14 unique categories in Köln-Innenstadt.

# %%
print (nearby_venues['categories'].value_counts()[0:15])
# Out:
# Plaza                   2
# Bavarian Restaurant     1
# Hotel                   1
# Beer Bar                1
# Art Museum              1
# Park                    1
# Jazz Club               1
# Lebanese Restaurant     1
# Gym / Fitness Center    1
# Toy / Game Store        1
# Steakhouse              1
# Pedestrian Plaza        1
# Ice Cream Shop          1
# Electronics Store       1
# Name: categories, dtype: int64

# %% [markdown]
# ***E: Exploration of the neighbourhoods in Cologne.***

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=3000, LIMIT=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']

    
    return(nearby_venues)

# %%
Cologne_venues = getNearbyVenues(names=df['City district'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Köln-Innenstadt
# Köln-Rodenkirchen
# Köln-Lindenthal
# Köln-Ehrenfeld
# Köln-Nippes
# Köln-Chorweiler
# Köln-Porz
# Köln-Kalk
# Köln-Mülheim

# %%
Cologne_venues.shape
# Out:
# (757, 7)

# %%
# Create a Data-Frame out of it to concentrate only on Restaurants 
Cologne_Venues_only_restaurant = Cologne_venues[Cologne_venues['Venue Category'].str.contains('Restaurant')].reset_index(drop=True)
Cologne_Venues_only_restaurant.index = np.arange(1, len(Cologne_Venues_only_restaurant )+1)

# %%
print (Cologne_Venues_only_restaurant['Venue Category'].value_counts())
# Out:
# Italian Restaurant               29
# German Restaurant                24
# Turkish Restaurant               13
# Restaurant                       13
# Sushi Restaurant                 12
# Greek Restaurant                 10
# French Restaurant                 9
# Vietnamese Restaurant             8
# Modern European Restaurant        7
# Middle Eastern Restaurant         7
# Tapas Restaurant                  5
# Thai Restaurant                   4
# Seafood Restaurant                4
# Asian Restaurant                  3
# Spanish Restaurant                3
# Mediterranean Restaurant          3
# Mexican Restaurant                3
# Japanese Restaurant               2
# Fast Food Restaurant              2
# Comfort Food Restaurant           2
# Austrian Restaurant               2
# Kurdish Restaurant                2
# Doner Restaurant                  2
# Indian Restaurant                 2
# Vegetarian / Vegan Restaurant     2
# Kebab Restaurant                  2
# Eastern European Restaurant       1
# Latin American Restaurant         1
# Schnitzel Restaurant              1
# Scandinavian Restaurant           1
# American Restaurant               1
# Theme Restaurant                  1
# Falafel Restaurant                1
# Chinese Restaurant                1
# Mongolian Restaurant              1
# Name: Venue Category, dtype: int64

# %%
print('There are {} unique categories.'.format(len(Cologne_Venues_only_restaurant['Venue Category'].unique())))
# Out:
# There are 35 unique categories.

# %%
# create a dataframe of top 10 categories
Cologne_Venues_Top10 = Cologne_Venues_only_restaurant['Venue Category'].value_counts()[0:10].to_frame(name='frequency')
Cologne_Venues_Top10=Cologne_Venues_Top10.reset_index()
Cologne_Venues_Top10.rename(index=str, columns={"index": "Venue_Category", "frequency": "Frequency"}, inplace=True)
Cologne_Venues_Top10
# Out:
#                Venue_Category  Frequency
# 0          Italian Restaurant         29
# 1           German Restaurant         24
# 2          Turkish Restaurant         13
# 3                  Restaurant         13
# 4            Sushi Restaurant         12
# 5            Greek Restaurant         10
# 6           French Restaurant          9
# 7       Vietnamese Restaurant          8
# 8  Modern European Restaurant          7
# 9   Middle Eastern Restaurant          7

# %%
import seaborn as sns
from matplotlib import pyplot as plt

s=sns.barplot(x="Venue_Category", y="Frequency", data=Cologne_5_Dist_Venues_Top10)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('10 Most Frequently Occuring Venues in 9 City Districts of Cologne', fontsize=15)
plt.xlabel("Venue Category", fontsize=15)
plt.ylabel ("Frequency", fontsize=15)
plt.savefig("Most_Freq_Venues1.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %% [markdown]
# ***F: Size of the dataframe that results.***

# %%
print ("Shape of the Data-Frame with Venue Category only Restaurant: ", Cologne_Venues_only_restaurant.shape)
Cologne_Venues_only_restaurant.head(75)
# Out:
# Shape of the Data-Frame with Venue Category only Restaurant:  (184, 7)
#          Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
#
# 48               Bei mir zu Haus       50.938106         6.852201
# 49              Sushi Bar Gan-Mi       50.939357         6.841919
# 50                         Manju       50.937213         6.836090
# 51                       Arizona       50.937810         6.881191
# 52                     Kebapland       50.950867         6.915642
# 53                 speisemeister       50.954853         6.917377
# 54                      Wallczka       50.955421         6.915682
# 55                 Haus Scholzen       50.947137         6.923044
# 56                    meer sehen       50.949153         6.919536
# 57                   Causas Peru       50.955786         6.905720
# 58                       Piccola       50.952924         6.912800
# 59                 Alanya Firini       50.954047         6.919833
# 60                   Stadtgarten       50.942688         6.935325
# 61                           Noa       50.938343         6.938688
# 62                Mercato Deluxe       50.948143         6.947496
# 63               Ristorante Faro       50.932146         6.920478
# 64                     Chum Chay       50.938611         6.940479
# 65                          NENI       50.942025         6.943620
# 66                   Eat Italian       50.937881         6.938920
# 67                        Carlos       50.930687         6.916110
# 68                      Momotaro       50.937724         6.942386
# 69                        Kaizen       50.932780         6.934363
# 70                        Ni Hao       50.936239         6.934570
# 71                   Tapeo Picus       50.930446         6.921195
# 72                Le Moissonnier       50.950796         6.952466
# 73                      NeoBiota       50.937909         6.942613
# 74                   Iltis Grill       50.964613         6.913024
# 75                        mikoto       50.933204         6.939779
#
#                 Venue Category
# 1             Sushi Restaurant
# 2             Sushi Restaurant
# 3    Middle Eastern Restaurant
# 4        Vietnamese Restaurant
# 5                   Restaurant
# 6        Vietnamese Restaurant
# 7   Modern European Restaurant
# 8            German Restaurant
# 9   Modern European Restaurant
# 10          Italian Restaurant
# 11          Italian Restaurant
# 12       Vietnamese Restaurant
# 13            Sushi Restaurant
# 14           French Restaurant
# 15          Italian Restaurant
# 16          Italian Restaurant
# 17           German Restaurant
# 18          Falafel Restaurant
# 19          Italian Restaurant
# 20        Schnitzel Restaurant
# 21   Middle Eastern Restaurant
# 22           French Restaurant
# 23          Italian Restaurant
# 24          Italian Restaurant
# 25     Scandinavian Restaurant
# 26           German Restaurant
# 27                  Restaurant
# 28          Italian Restaurant
# 29           German Restaurant
# 30          Italian Restaurant
# 31           German Restaurant
# 32           German Restaurant
# 33            Sushi Restaurant
# 34           German Restaurant
# 35          Mexican Restaurant
# 36           German Restaurant
# 37         Japanese Restaurant
# 38          Seafood Restaurant
# 39           German Restaurant
# 40            Sushi Restaurant
# 41                  Restaurant
# 42           German Restaurant
# 43            Greek Restaurant
# 44            Greek Restaurant
# 45  Modern European Restaurant
# 46           French Restaurant
# 47             Thai Restaurant
# 48           German Restaurant
# 49            Sushi Restaurant
# 50           Indian Restaurant
# 51         American Restaurant
# 52            Kebab Restaurant
# 53                  Restaurant
# 54            Tapas Restaurant
# 55           German Restaurant
# 56            Tapas Restaurant
# 57   Latin American Restaurant
# 58          Italian Restaurant
# 59          Turkish Restaurant
# 60           German Restaurant
# 61  Modern European Restaurant
# 62          Italian Restaurant
# 63          Italian Restaurant
# 64       Vietnamese Restaurant
# 65   Middle Eastern Restaurant
# 66          Italian Restaurant
# 67          Spanish Restaurant
# 68            Sushi Restaurant
# 69         Japanese Restaurant
# 70          Chinese Restaurant
# 71            Tapas Restaurant
# 72           French Restaurant
# 73                  Restaurant
# 74            Greek Restaurant
# 75            Sushi Restaurant

# %%
Cologne_Venues_restaurant = Cologne_Venues_only_restaurant.groupby(['Neighborhood'])['Venue Category'].apply(lambda x: x[x.str.contains('Restaurant')].count())

# %% [markdown]
# ***G: Analysis of the neighbourhoods.***

# %%
Cologne_Venues_restaurant
# Out:
# Neighborhood
# Köln-Chorweiler       3
# Köln-Ehrenfeld       26
# Köln-Innenstadt      24
# Köln-Kalk            24
# Köln-Lindenthal      24
# Köln-Mülheim         21
# Köln-Nippes          31
# Köln-Porz            28
# Köln-Rodenkirchen     3
# Name: Venue Category, dtype: int64

# %%
Cologne_Venues_restaurant_df  = Cologne_Venues_restaurant.to_frame().reset_index()
Cologne_Venues_restaurant_df.columns = ['Neighborhood', 'Number of Restaurant']
Cologne_Venues_restaurant_df.index = np.arange(1, len(Cologne_Venues_restaurant_df)+1)
list_rest_no =Cologne_Venues_restaurant_df['Number of Restaurant'].to_list()
list_dist =Cologne_Venues_restaurant_df['Neighborhood'].to_list()

# %%
# one hot encoding
Cologne_onehot = pd.get_dummies(Cologne_Venues_only_restaurant[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Cologne_onehot['Neighborhood'] = Cologne_Venues_only_restaurant['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [Cologne_onehot.columns[-1]] + list(Cologne_onehot.columns[:-1])
Cologne_onehot = Cologne_onehot[fixed_columns]

Cologne_onehot.head()
# Out:
#       Neighborhood  American Restaurant  Asian Restaurant  \
# 1  Köln-Innenstadt                    0                 0
# 2  Köln-Innenstadt                    0                 0
# 3  Köln-Innenstadt                    0                 0
# 4  Köln-Innenstadt                    0                 0
# 5  Köln-Innenstadt                    0                 0
#
#    Austrian Restaurant  Chinese Restaurant  Comfort Food Restaurant  \
# 1                    0                   0                        0
# 2                    0                   0                        0
# 3                    0                   0                        0
# 4                    0                   0                        0
# 5                    0                   0                        0
#
#    Doner Restaurant  Eastern European Restaurant  Falafel Restaurant  \
# 1                 0                            0                   0
# 2                 0                            0                   0
# 3                 0                            0                   0
# 4                 0                            0                   0
# 5                 0                            0                   0
#
#    Fast Food Restaurant  French Restaurant  German Restaurant  \
# 1                     0                  0                  0
# 2                     0                  0                  0
# 3                     0                  0                  0
# 4                     0                  0                  0
# 5                     0                  0                  0
#
#    Greek Restaurant  Indian Restaurant  Italian Restaurant  \
# 1                 0                  0                   0
# 2                 0                  0                   0
# 3                 0                  0                   0
# 4                 0                  0                   0
# 5                 0                  0                   0
#
#    Japanese Restaurant  Kebab Restaurant  Kurdish Restaurant  \
# 1                    0                 0                   0
# 2                    0                 0                   0
# 3                    0                 0                   0
# 4                    0                 0                   0
# 5                    0                 0                   0
#
#    Latin American Restaurant  Mediterranean Restaurant  Mexican Restaurant  \
# 1                          0                         0                   0
# 2                          0                         0                   0
# 3                          0                         0                   0
# 4                          0                         0                   0
# 5                          0                         0                   0
#
#    Middle Eastern Restaurant  Modern European Restaurant  \
# 1                          0                           0
# 2                          0                           0
# 3                          1                           0
# 4                          0                           0
# ----Köln-Porz----
#                 venue  freq
# 0   German Restaurant  0.25
# 1  Italian Restaurant  0.18
# 2          Restaurant  0.11
# 3  Seafood Restaurant  0.07
# 4     Thai Restaurant  0.07
# 5   French Restaurant  0.07
# 6    Greek Restaurant  0.07
# 7  Mexican Restaurant  0.04
# 8  Turkish Restaurant  0.04
# 9    Sushi Restaurant  0.04
#
#
# ----Köln-Rodenkirchen----
#                         venue  freq
# 0                  Restaurant  0.33
# 1     Scandinavian Restaurant  0.33
# 2           German Restaurant  0.33
# 3         American Restaurant  0.00
# 4    Mediterranean Restaurant  0.00
# 5   Middle Eastern Restaurant  0.00
# 6  Modern European Restaurant  0.00
# 7        Mongolian Restaurant  0.00
# 8        Schnitzel Restaurant  0.00
# 9          Seafood Restaurant  0.00

# %% [markdown]
# ***J: Creating a pandas dataframe.***

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Cologne_grouped['Neighborhood']

for ind in np.arange(Cologne_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Cologne_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(23)
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0    Köln-Chorweiler  Fast Food Restaurant    Italian Restaurant
# 1     Köln-Ehrenfeld      Tapas Restaurant    Italian Restaurant
# 2    Köln-Innenstadt    Italian Restaurant      Sushi Restaurant
# 3          Köln-Kalk      Greek Restaurant    Turkish Restaurant
# 4    Köln-Lindenthal     German Restaurant      Sushi Restaurant
# 5       Köln-Mülheim    Turkish Restaurant    Italian Restaurant
# 6        Köln-Nippes    Italian Restaurant     French Restaurant
# 7          Köln-Porz     German Restaurant    Italian Restaurant
# 8  Köln-Rodenkirchen     German Restaurant            Restaurant
#
#      3rd Most Common Venue      4th Most Common Venue  \
# 0         Sushi Restaurant      Vietnamese Restaurant
# 1               Restaurant          German Restaurant
# 2    Vietnamese Restaurant          German Restaurant
# 3       Italian Restaurant  Middle Eastern Restaurant
# 4       Italian Restaurant           Greek Restaurant
# 5         Asian Restaurant   Mediterranean Restaurant
# 6    Vietnamese Restaurant        Austrian Restaurant
# 7               Restaurant           Greek Restaurant
# 8  Scandinavian Restaurant      Vietnamese Restaurant
#
#         5th Most Common Venue          6th Most Common Venue  \
# 0         Japanese Restaurant              Indian Restaurant
# 1            Sushi Restaurant          Vietnamese Restaurant
# 2           French Restaurant      Middle Eastern Restaurant
# 3                  Restaurant              German Restaurant
# 4         American Restaurant              Indian Restaurant
# 5           German Restaurant  Vegetarian / Vegan Restaurant
# 6  Modern European Restaurant               Greek Restaurant
# 7             Thai Restaurant             Seafood Restaurant
# 8            Kebab Restaurant             Italian Restaurant
#
#         7th Most Common Venue      8th Most Common Venue  \
# 0            Greek Restaurant          German Restaurant
# 1  Modern European Restaurant         Chinese Restaurant
# 2  Modern European Restaurant                 Restaurant
# 3           Indian Restaurant         Kurdish Restaurant
# 4           French Restaurant         Mexican Restaurant
# 5            Greek Restaurant  Middle Eastern Restaurant
# 6                  Restaurant           Sushi Restaurant
# 7           French Restaurant       Fast Food Restaurant
# 8           Indian Restaurant           Greek Restaurant
#
#            9th Most Common Venue    10th Most Common Venue
# 0              French Restaurant        Falafel Restaurant
# 1              French Restaurant          Greek Restaurant
# 2           Schnitzel Restaurant        Falafel Restaurant
# 3  Vegetarian / Vegan Restaurant  Mediterranean Restaurant
# 4     Modern European Restaurant                Restaurant
# 5          Vietnamese Restaurant        Seafood Restaurant
# 6              German Restaurant        Spanish Restaurant
# 7             Turkish Restaurant        Kurdish Restaurant
# 8              French Restaurant      Fast Food Restaurant

# %% [markdown]
# ***K: Clustering the neighbourhoods with k-means.***

# %%
# set number of clusters (I choose 5)
kclusters = 5

Cologne_grouped_clustering = Cologne_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Cologne_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 2, 2, 2, 4, 0, 2, 4, 1], dtype=int32)

# %%
Cologne_merged = df
Cologne_merged.head(10)
# Out:
#        City district                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5    Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6          Köln-Porz  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7          Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8       Köln-Mülheim  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
# 5  67.2 km²      80.870    1.204/km²
# 6  78.8 km²     106.520    1.352/km²
# 7  38.2 km²     108.330    2.841/km²
# 8  52.2 km²     144.374    2.764/km²
#
#                                    District Councils   Latitude  Longitude
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...  50.906705   6.999129
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
# 8    Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln  50.958147   7.013526

# %%
neighborhoods_venues_sorted.head(23)
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0    Köln-Chorweiler  Fast Food Restaurant    Italian Restaurant
# 1     Köln-Ehrenfeld      Tapas Restaurant    Italian Restaurant
# 2    Köln-Innenstadt    Italian Restaurant      Sushi Restaurant
# 3          Köln-Kalk      Greek Restaurant    Turkish Restaurant
# 4    Köln-Lindenthal     German Restaurant      Sushi Restaurant
# 5       Köln-Mülheim    Turkish Restaurant    Italian Restaurant
# 6        Köln-Nippes    Italian Restaurant     French Restaurant
# 7          Köln-Porz     German Restaurant    Italian Restaurant
# 8  Köln-Rodenkirchen     German Restaurant            Restaurant
#
#      3rd Most Common Venue      4th Most Common Venue  \
# 0         Sushi Restaurant      Vietnamese Restaurant
# 1               Restaurant          German Restaurant
# 2    Vietnamese Restaurant          German Restaurant
# 3       Italian Restaurant  Middle Eastern Restaurant
# 4       Italian Restaurant           Greek Restaurant
# 5         Asian Restaurant   Mediterranean Restaurant
# 6    Vietnamese Restaurant        Austrian Restaurant
# 7               Restaurant           Greek Restaurant
# 8  Scandinavian Restaurant      Vietnamese Restaurant
#
#         5th Most Common Venue          6th Most Common Venue  \
# 0         Japanese Restaurant              Indian Restaurant
# 1            Sushi Restaurant          Vietnamese Restaurant
# 2           French Restaurant      Middle Eastern Restaurant
# 3                  Restaurant              German Restaurant
# 4         American Restaurant              Indian Restaurant
# 5           German Restaurant  Vegetarian / Vegan Restaurant
# 6  Modern European Restaurant               Greek Restaurant
# 7             Thai Restaurant             Seafood Restaurant
# 8            Kebab Restaurant             Italian Restaurant
#
#         7th Most Common Venue      8th Most Common Venue  \
# 0            Greek Restaurant          German Restaurant
# 1  Modern European Restaurant         Chinese Restaurant
# 2  Modern European Restaurant                 Restaurant
# 3           Indian Restaurant         Kurdish Restaurant
# 4           French Restaurant         Mexican Restaurant
# 5            Greek Restaurant  Middle Eastern Restaurant
# 6                  Restaurant           Sushi Restaurant
# 7           French Restaurant       Fast Food Restaurant
# 8           Indian Restaurant           Greek Restaurant
#
#            9th Most Common Venue    10th Most Common Venue
# 0              French Restaurant        Falafel Restaurant
# 1              French Restaurant          Greek Restaurant
# 2           Schnitzel Restaurant        Falafel Restaurant
# 3  Vegetarian / Vegan Restaurant  Mediterranean Restaurant
# 4     Modern European Restaurant                Restaurant
# 5          Vietnamese Restaurant        Seafood Restaurant
# 6              German Restaurant        Spanish Restaurant
# 7             Turkish Restaurant        Kurdish Restaurant
# 8              French Restaurant      Fast Food Restaurant

# %%
neighborhoods_venues_sorted_w_clusters = neighborhoods_venues_sorted

# %%
neighborhoods_venues_sorted_w_clusters.head(9)
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0    Köln-Chorweiler  Fast Food Restaurant    Italian Restaurant
# 1     Köln-Ehrenfeld      Tapas Restaurant    Italian Restaurant
# 2    Köln-Innenstadt    Italian Restaurant      Sushi Restaurant
# 3          Köln-Kalk      Greek Restaurant    Turkish Restaurant
# 4    Köln-Lindenthal     German Restaurant      Sushi Restaurant
# 5       Köln-Mülheim    Turkish Restaurant    Italian Restaurant
# 6        Köln-Nippes    Italian Restaurant     French Restaurant
# 7          Köln-Porz     German Restaurant    Italian Restaurant
# 8  Köln-Rodenkirchen     German Restaurant            Restaurant
#
#      3rd Most Common Venue      4th Most Common Venue  \
# 0         Sushi Restaurant      Vietnamese Restaurant
# 1               Restaurant          German Restaurant
# 2    Vietnamese Restaurant          German Restaurant
# 3       Italian Restaurant  Middle Eastern Restaurant
# 4       Italian Restaurant           Greek Restaurant
# 5         Asian Restaurant   Mediterranean Restaurant
# 6    Vietnamese Restaurant        Austrian Restaurant
# 7               Restaurant           Greek Restaurant
# 8  Scandinavian Restaurant      Vietnamese Restaurant
#
#         5th Most Common Venue          6th Most Common Venue  \
# 0         Japanese Restaurant              Indian Restaurant
# 1            Sushi Restaurant          Vietnamese Restaurant
# 2           French Restaurant      Middle Eastern Restaurant
# 3                  Restaurant              German Restaurant
# 4         American Restaurant              Indian Restaurant
# 5           German Restaurant  Vegetarian / Vegan Restaurant
# 6  Modern European Restaurant               Greek Restaurant
# 7             Thai Restaurant             Seafood Restaurant
# 8            Kebab Restaurant             Italian Restaurant
#
#         7th Most Common Venue      8th Most Common Venue  \
# 0            Greek Restaurant          German Restaurant
# 1  Modern European Restaurant         Chinese Restaurant
# 2  Modern European Restaurant                 Restaurant
# 3           Indian Restaurant         Kurdish Restaurant
# 4           French Restaurant         Mexican Restaurant
# 5            Greek Restaurant  Middle Eastern Restaurant
# 6                  Restaurant           Sushi Restaurant
# 7           French Restaurant       Fast Food Restaurant
# 8           Indian Restaurant           Greek Restaurant
#
#            9th Most Common Venue    10th Most Common Venue
# 0              French Restaurant        Falafel Restaurant
# 1              French Restaurant          Greek Restaurant
# 2           Schnitzel Restaurant        Falafel Restaurant
# 3  Vegetarian / Vegan Restaurant  Mediterranean Restaurant
# 4     Modern European Restaurant                Restaurant
# 5          Vietnamese Restaurant        Seafood Restaurant
# 6              German Restaurant        Spanish Restaurant
# 7             Turkish Restaurant        Kurdish Restaurant
# 8              French Restaurant      Fast Food Restaurant

# %%
# add clustering labels
neighborhoods_venues_sorted_w_clusters.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
neighborhoods_venues_sorted_w_clusters.head(23)
# Out:
#    Cluster Labels       Neighborhood 1st Most Common Venue  \
# 0               3    Köln-Chorweiler  Fast Food Restaurant
# 1               2     Köln-Ehrenfeld      Tapas Restaurant
# 2               2    Köln-Innenstadt    Italian Restaurant
# 3               2          Köln-Kalk      Greek Restaurant
# 4               4    Köln-Lindenthal     German Restaurant
# 5               0       Köln-Mülheim    Turkish Restaurant
# 6               2        Köln-Nippes    Italian Restaurant
# 7               4          Köln-Porz     German Restaurant
# 8               1  Köln-Rodenkirchen     German Restaurant
#
#   2nd Most Common Venue    3rd Most Common Venue      4th Most Common Venue  \
# 0    Italian Restaurant         Sushi Restaurant      Vietnamese Restaurant
# 1    Italian Restaurant               Restaurant          German Restaurant
# 2      Sushi Restaurant    Vietnamese Restaurant          German Restaurant
# 3    Turkish Restaurant       Italian Restaurant  Middle Eastern Restaurant
# 4      Sushi Restaurant       Italian Restaurant           Greek Restaurant
# 5    Italian Restaurant         Asian Restaurant   Mediterranean Restaurant
# 6     French Restaurant    Vietnamese Restaurant        Austrian Restaurant
# 7    Italian Restaurant               Restaurant           Greek Restaurant
# 8            Restaurant  Scandinavian Restaurant      Vietnamese Restaurant
#
#         5th Most Common Venue          6th Most Common Venue  \
# 0         Japanese Restaurant              Indian Restaurant
# 1            Sushi Restaurant          Vietnamese Restaurant
# 2           French Restaurant      Middle Eastern Restaurant
# 3                  Restaurant              German Restaurant
# 4         American Restaurant              Indian Restaurant
# 5           German Restaurant  Vegetarian / Vegan Restaurant
# 6  Modern European Restaurant               Greek Restaurant
# 7             Thai Restaurant             Seafood Restaurant
# 8            Kebab Restaurant             Italian Restaurant
#
#         7th Most Common Venue      8th Most Common Venue  \
# 0            Greek Restaurant          German Restaurant
# 1  Modern European Restaurant         Chinese Restaurant
# 2  Modern European Restaurant                 Restaurant
# 3           Indian Restaurant         Kurdish Restaurant
# 4           French Restaurant         Mexican Restaurant
# 5            Greek Restaurant  Middle Eastern Restaurant
# 6                  Restaurant           Sushi Restaurant
# 7           French Restaurant       Fast Food Restaurant
# 8           Indian Restaurant           Greek Restaurant
#
#            9th Most Common Venue    10th Most Common Venue
# 0              French Restaurant        Falafel Restaurant
# 1              French Restaurant          Greek Restaurant
# 2           Schnitzel Restaurant        Falafel Restaurant
# 3  Vegetarian / Vegan Restaurant  Mediterranean Restaurant
# 4     Modern European Restaurant                Restaurant
# 5          Vietnamese Restaurant        Seafood Restaurant
# 6              German Restaurant        Spanish Restaurant
# 7             Turkish Restaurant        Kurdish Restaurant
# 8              French Restaurant      Fast Food Restaurant

# %%
Cologne_merged.rename(columns={'City district':'Neighborhood'}, inplace=True)

Cologne_merged = Cologne_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

Cologne_merged.head(10)
# Out:
#         Neighborhood                                         City parts  \
# 0    Köln-Innenstadt  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 1  Köln-Rodenkirchen  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
# 2    Köln-Lindenthal  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 3     Köln-Ehrenfeld  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4        Köln-Nippes  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 5    Köln-Chorweiler  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
# 6          Köln-Porz  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
# 7          Köln-Kalk  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
# 8       Köln-Mülheim  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#        Area Population1 Pop. density  \
# 0  16.4 km²     127.033    7.746/km²
# 1  54.6 km²     100.936    1.850/km²
# 2  41.6 km²     137.552    3.308/km²
# 3  23.8 km²     103.621    4.348/km²
# 4  31.8 km²     110.092    3.462/km²
# 5  67.2 km²      80.870    1.204/km²
# 6  78.8 km²     106.520    1.352/km²
# 7  38.2 km²     108.330    2.841/km²
# 8  52.2 km²     144.374    2.764/km²
#
#                                    District Councils   Latitude  Longitude  \
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...  50.906705   6.999129
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
# 8    Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln  50.958147   7.013526
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               2    Italian Restaurant      Sushi Restaurant
# 1               1     German Restaurant            Restaurant
# 2               4     German Restaurant      Sushi Restaurant
# 3               2      Tapas Restaurant    Italian Restaurant
# 4               2    Italian Restaurant     French Restaurant
# 5               3  Fast Food Restaurant    Italian Restaurant
# 6               4     German Restaurant    Italian Restaurant
# 7               2      Greek Restaurant    Turkish Restaurant
# 8               0    Turkish Restaurant    Italian Restaurant
#
#      3rd Most Common Venue      4th Most Common Venue  \
# 0    Vietnamese Restaurant          German Restaurant
# 1  Scandinavian Restaurant      Vietnamese Restaurant
# 2       Italian Restaurant           Greek Restaurant
# 3               Restaurant          German Restaurant
# 4    Vietnamese Restaurant        Austrian Restaurant
# 5         Sushi Restaurant      Vietnamese Restaurant
# 6               Restaurant           Greek Restaurant
# 7       Italian Restaurant  Middle Eastern Restaurant
# 8         Asian Restaurant   Mediterranean Restaurant
#
#         5th Most Common Venue          6th Most Common Venue  \
# 0           French Restaurant      Middle Eastern Restaurant
# 1            Kebab Restaurant             Italian Restaurant
# 2         American Restaurant              Indian Restaurant
# 3            Sushi Restaurant          Vietnamese Restaurant
# 4  Modern European Restaurant               Greek Restaurant
# 5         Japanese Restaurant              Indian Restaurant
# 6             Thai Restaurant             Seafood Restaurant
# 7                  Restaurant              German Restaurant
# 8           German Restaurant  Vegetarian / Vegan Restaurant
#
#         7th Most Common Venue      8th Most Common Venue  \
# 0  Modern European Restaurant                 Restaurant
# 1           Indian Restaurant           Greek Restaurant
# 2           French Restaurant         Mexican Restaurant
# 3  Modern European Restaurant         Chinese Restaurant
# 4                  Restaurant           Sushi Restaurant
# 5            Greek Restaurant          German Restaurant
# 6           French Restaurant       Fast Food Restaurant
# 7           Indian Restaurant         Kurdish Restaurant
# 8            Greek Restaurant  Middle Eastern Restaurant
#
#            9th Most Common Venue    10th Most Common Venue
# 0           Schnitzel Restaurant        Falafel Restaurant
# 1              French Restaurant      Fast Food Restaurant
# 2     Modern European Restaurant                Restaurant
# 3              French Restaurant          Greek Restaurant
# 4              German Restaurant        Spanish Restaurant
# 5              French Restaurant        Falafel Restaurant
# 6             Turkish Restaurant        Kurdish Restaurant
# 7  Vegetarian / Vegan Restaurant  Mediterranean Restaurant
# 8          Vietnamese Restaurant        Seafood Restaurant

# %% [markdown]
# Finally, let's visualize the resulting clusters.

# %%
# create a map with folium
map_restaurants10 = folium.Map(location=[latitude,longitude], tiles='cartodbpositron', 
                               attr="<a href=https://github.com/python-visualization/folium/>Folium</a>")

# set color scheme for the five clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
for lat, lon, poi, cluster in zip(Cologne_merged['Latitude'], 
                                  Cologne_merged['Longitude'], 
                                  Cologne_merged['Neighborhood'], 
                                  Cologne_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=list_rest_no[list_dist.index(poi)]*0.5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_restaurants10)
       
map_restaurants10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ***L: Examination of the 5 clusters.***

# %% [markdown]
# Now, we can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, we can then assign a name to each cluster.

# %% [markdown]
# ***Cluster 1***

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 0, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 8  Buchforst, Buchheim, Dellbrück, Dünnwald, Flit...
#
#                                  District Councils   Latitude  Longitude  \
# 8  Bezirksamt Mülheim Wiener Platz 2a,D-51065 Köln  50.958147   7.013526
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 8               0    Turkish Restaurant    Italian Restaurant
#
#   3rd Most Common Venue     4th Most Common Venue 5th Most Common Venue  \
# 8      Asian Restaurant  Mediterranean Restaurant     German Restaurant
#
#            6th Most Common Venue 7th Most Common Venue  \
# 8  Vegetarian / Vegan Restaurant      Greek Restaurant
#
#        8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 8  Middle Eastern Restaurant  Vietnamese Restaurant     Seafood Restaurant

# %% [markdown]
# Cluster 1 could be called the Turkish cluster.

# %% [markdown]
# ***Cluster 2***

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 1, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 1  Bayenthal, Godorf, Hahnwald, Immendorf, Marien...
#
#                                    District Councils   Latitude  Longitude  \
# 1  Bezirksamt Rodenkirchen Hauptstraße 85, D-5099...  50.865622   6.969718
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1               1     German Restaurant            Restaurant
#
#      3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 1  Scandinavian Restaurant  Vietnamese Restaurant      Kebab Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1    Italian Restaurant     Indian Restaurant      Greek Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 1     French Restaurant   Fast Food Restaurant

# %% [markdown]
# Cluster 2 could be called the Northern European cluster.

# %% [markdown]
# ***Cluster 3***

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 2, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 0  Altstadt-Nord, Altstadt-Süd, Deutz, Neustadt-N...
# 3  Bickendorf, Bocklemünd/Mengenich, Ehrenfeld, N...
# 4  Bilderstöckchen, Longerich, Mauenheim, Niehl, ...
# 7  Brück, Höhenberg, Humboldt/Gremberg, Kalk, Mer...
#
#                                    District Councils   Latitude  Longitude  \
# 0  Bezirksksamt Innenstadt Brückenstraße 19, D-50...  50.937328   6.959234
# 3  Bezirksamt Ehrenfeld Venloer Straße 419 – 421,...  50.951502   6.916529
# 4   Bezirksamt NippesNeusser Straße 450,D-50733 Köln  50.958994   6.941777
# 7  Bezirksamt KalkKalker Hauptstraße 247–273,D-51...  50.931923   7.005806
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               2    Italian Restaurant      Sushi Restaurant
# 3               2      Tapas Restaurant    Italian Restaurant
# 4               2    Italian Restaurant     French Restaurant
# 7               2      Greek Restaurant    Turkish Restaurant
#
#    3rd Most Common Venue      4th Most Common Venue  \
# 0  Vietnamese Restaurant          German Restaurant
# 3             Restaurant          German Restaurant
# 4  Vietnamese Restaurant        Austrian Restaurant
# 7     Italian Restaurant  Middle Eastern Restaurant
#
#         5th Most Common Venue      6th Most Common Venue  \
# 0           French Restaurant  Middle Eastern Restaurant
# 3            Sushi Restaurant      Vietnamese Restaurant
# 4  Modern European Restaurant           Greek Restaurant
# 7                  Restaurant          German Restaurant
#
#         7th Most Common Venue 8th Most Common Venue  \
# 0  Modern European Restaurant            Restaurant
# 3  Modern European Restaurant    Chinese Restaurant
# 4                  Restaurant      Sushi Restaurant
# 7           Indian Restaurant    Kurdish Restaurant
#
#            9th Most Common Venue    10th Most Common Venue
# 0           Schnitzel Restaurant        Falafel Restaurant
# 3              French Restaurant          Greek Restaurant
# 4              German Restaurant        Spanish Restaurant
# 7  Vegetarian / Vegan Restaurant  Mediterranean Restaurant

# %% [markdown]
# Cluster 3 could be called the Mediterranean cluster.

# %% [markdown]
# ***Cluster 4***

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 3, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 5  Blumenberg, Chorweiler, Esch/Auweiler, Fühling...
#
#                                    District Councils   Latitude  Longitude  \
# 5  Bezirksamt Chorweiler Pariser Platz 1, D-50765...  51.021167   6.898034
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 5               3  Fast Food Restaurant    Italian Restaurant
#
#   3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 5      Sushi Restaurant  Vietnamese Restaurant   Japanese Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 5     Indian Restaurant      Greek Restaurant     German Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 5     French Restaurant     Falafel Restaurant

# %% [markdown]
# Cluster 4 could be called the Fast Food cluster.

# %% [markdown]
# ***Cluster 5***

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 4, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                           City parts  \
# 2  Braunsfeld, Junkersdorf, Klettenberg, Lindenth...
# 6  Eil, Elsdorf, Ensen, Finkenberg, Gremberghoven...
#
#                                    District Councils   Latitude  Longitude  \
# 2  Bezirksamt Lindenthal Aachener Straße 220, 509...  50.935935   6.871246
# 6  Bezirksamt PorzFriedrich-Ebert-Ufer 64–70, D-5...  50.906705   6.999129
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2               4     German Restaurant      Sushi Restaurant
# 6               4     German Restaurant    Italian Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2    Italian Restaurant      Greek Restaurant   American Restaurant
# 6            Restaurant      Greek Restaurant       Thai Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2     Indian Restaurant     French Restaurant    Mexican Restaurant
# 6    Seafood Restaurant     French Restaurant  Fast Food Restaurant
#
#         9th Most Common Venue 10th Most Common Venue
# 2  Modern European Restaurant             Restaurant
# 6          Turkish Restaurant     Kurdish Restaurant

# %% [markdown]
# Cluster 5 could be called the German/diverse cluster.

# %% [markdown]
# # That's it. Thanks for reading!
